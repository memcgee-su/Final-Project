# %%
def sentiment():
    moods = ["happy", "sad", "goofy", "festive", "curious", "girly", "adventurous", "childish", "mysterious", "romantic", "nostalgic", "dramatic", "edgy", "active"]
    while True:
        for mood in moods:
            print("Are you %s " % (mood))
        mood = input("Enter which mood you are currently in from the list above.: ")
        if mood not in moods:
            print("\nMood entered is NOT in list. Please enter a mood from the list.")
        else:
            return mood
    
def netflix_rec():
    print('Netflix Time! ')
    feelings = sentiment()
    
    if feelings == 'happy':
        recommendation = (f"\nSince you are feeling {feelings}, here are some TV genres to look at: Comedies, Holidays, Stand-Up and Talk Shows\n")
        recommendation1 = ("\nTop 5 Comedies: \n1a. Fuller House \n2a. Merry Happy Whatever \n3a. New Girl \n4a. Atypical \n5a. Schitts Creek\n")
        recommendation2 = ("\nTop 5 Holidays: \n1b. Merry Happy Whatever \n2b. The Knight Before Christmas \n3b. Christmas Prince: The Royal Baby \n4b. How the Grinch Stole Christmas \n5b. Christmas with the Kranks\n")
        recommendation3 = ("\nTop 5 Stand-Up and Talk Shows: \n1c. Kevin Hart Seriously Funny \n2c. Tom Segura: Disgraceful \n3c. Michelle Wolf Joke Show \n4c. Kevin Hart: Laugh at my pain \n5c. Adam Sandler 100% Fresh\n")
        recommendation4 = (" ")
        recommendation5 = (" ")
        
    elif feelings == 'sad':
        recommendation = (f"\nSince you are feeling {feelings}, here are some TV genres to look at: Comedies, Romance, Stand-Up and Talk Shows\n")
        recommendation1 = ("\nTop 5 Comedies: \n1a. Fuller House \n2a. Merry Happy Whatever \n3a. New Girl \n4a. Atypical \n5a. Schitts Creek\n")
        recommendation2 = ("\nTop 5 Romance: \n1b. The L Word \n2b. Friends from Collage \n3b. Greys Anatomy \n4b. Jane the Virgin \n5b. Gilmore Girls\n")
        recommendation3 = ("\nTop 5 Stand-Up and Talk Shows: \n1c. Kevin Hart Seriously Funny \n2c. Tom Segura: Disgraceful \n3c. Michelle Wolf Joke Show \n4c. Kevin Hart: Laugh at my pain \n5c. Adam Sandler 100% Fresh\n")
        recommendation4 = (" ")
        recommendation5 = (" ")
        
    elif feelings == 'goofy':
        recommendation = (f"\nSince you are feeling {feelings}, here are some TV genres to look at: Action, Comedies, Stand-Up and Talk Shows\n")
        recommendation1 = ("\nTop 5 Action: \n1a. Daredevil \n2a. Jessica Jones \n3a. Luke Cage \n4a. The Umbrella Academy \n5a. Narcos\n")
        recommendation2 = ("\nTop 5 Comedies: \n1b. Fuller House \n2b. Merry Happy Whatever \n3b. New Girl \n4b. Atypical \n5b. Schitts Creek\n")
        recommendation3 = ("\nTop 5 Stand-Up and Talk Shows: \n1c. Kevin Hart Seriously Funny \n2c. Tom Segura: Disgraceful \n3c. Michelle Wolf Joke Show \n4c. Kevin Hart: Laugh at my pain \n5c. Adam Sandler 100% Fresh\n")
        recommendation4 = (" ")
        recommendation5 = (" ")
        
    elif feelings == 'festive':
        recommendation = ("Unfortunately, there are no festive TV shows.")
        recommendation1 = (" ")
        recommendation2 = (" ")
        recommendation3 = (" ")
        recommendation4 = (" ")
        recommendation5 = (" ")
        
    elif feelings == 'curious':
        recommendation = (f"\nSince you are feeling {feelings}, here are some TV genres to look at: Crime, Sci-Fi and Fantasy, Science and Nature, and Thrillers\n")
        recommendation1 = ("\nTop 5 Crime: \n1a. Dirty John \n2a. You \n3a. How to get away with Murder \n4a. Criminal Minds \n5a. Blacklist\n")
        recommendation2 = ("\nTop 5 Sci-Fi and Fantasy: \n1b. The Vampire Diaries \n2b. Lucifer \n3b. Outlander \n4b. The I-Land \n5.b Once Upon a Time\n")
        recommendation3 = ("\nTop 5 Science and Nature: \n1c. Our Planet \n2c. Meat Eater \n3c. The Mind Explained \n4c. Brain Games \n5c. Wild Alaska\n")
        recommendation4 = ("\nTop 5 Thrillers: \n1d. You \n2d. Breaking Bad \n3d. Designated Survivor \n4d. Dirty John \n5d. Quantico\n")
        recommendation5 = (" ")
        
    elif feelings == 'girly':
        recommendation = (f"\nSince you are feeling {feelings}, here are some TV genres to look at: Dramas\n")
        recommendation1 = ("\nTop 5 Dramas: \n1a. Dirty John \n2a. Scandal \n3a. The Vampire Diaries \n4a. Dynasty \n5a. Dexter\n")
        recommendation2 = (" ")
        recommendation3 = (" ")
        recommendation4 = (" ")
        recommendation5 = (" ")
        
    elif feelings == 'adventurous':
        recommendation = (f"\nSince you are feeling {feelings}, here are some TV genres to look at: British, Crime, International, Sci-Fi and Fantasy, Science and Nature\n")
        recommendation1 = ("\nTop 5 British: \n1a. The Crown \n2a. Peaky Blinders \n3a. Black Mirror \n4a. Doctor Foster \n5a. Bodyguard\n")
        recommendation2 = ("\nTop 5 Crime: \n1b. Dirty John \n2b. You \n3b. How to get away with Murder \n4b. Criminal Minds \n5b. Blacklist\n")
        recommendation3 = ("\nTop 5 International: \n1c. Money Heist \n2c. Baby \n3c. Home for Christmas \n4c. Elites \n5c. Cable Girls\n")
        recommendation4 = ("\nTop 5 Sci-Fi and Fantasy: \n1d. The Vampire Diaries \n2d. Lucifer \n3d. Outlander \n4d. The I-Land \n5d. Once Upon a Time\n")
        recommendation5 = ("\nTop 5 Science and Nature: \n1e. Our Planet \n2e. Meat Eater \n3e. The Mind Explained \n4e. Brain Games \n5e. Wild Alaska\n")
        
    elif feelings == 'childish':
        recommendation = (f"\nSince you are feeling {feelings}, here are some TV genres to look at: Anime and Kids\n")
        recommendation1 = ("\nTop 5 Anime: \n1a. Naruto \n2a. The Seven Deadly Sins \n3a. Sword Art Online \n4a. Black Butler \n5a. Hunter X Hunter\n")
        recommendation2 = ("\nTop 5 Kids: \n1b. Sam and Cat \n2b. Raising Dion \n3b. Victorious \n4b. The Boss Baby: Back in Business \n5b. Barbie: Living in a Dream House\n")
        recommendation3 = (" ")
        recommendation4 = (" ")
        recommendation5 = (" ")
        
    elif feelings == 'mysterious':
        recommendation = (f"\nSince you are feeling {feelings}, here are some TV genres to look at: Action, Horror, Mysteries, and Thrillers\n")
        recommendation1 = ("\nTop 5 Action: \n1a. Daredevil \n2a. Jessica Jones \n3a. Luke Cage \n4a. The Umbrella Academy \n5a. Narcos\n")
        recommendation2 = ("\nTop 5 Horror: \n1b. V Wars \n2b. American Horror Story \n3b. The Walking Dead \n4b. The Originals \n5b. Supernaturals\n")
        recommendation3 = ("\nTop 5 Mysteries: \n1c. How to get away with Murder \n2c. Criminal Minds \n3c. Dexter \n4c. Sherlock \n5c. Person of Interest\n")
        recommendation4 = ("\nTop 5 Thrillers: \n1d. You \n2d. Breaking Bad \n3d. Designated Survivor \n4d. Dirty John \n5d. Quantico\n")
        recommendation5 = (" ")
        
    elif feelings == 'romantic':
        recommendation = (f"\nSince you are feeling {feelings}, here are some TV genres to look at: Dramas and Romance\n")
        recommendation1 = ("\nTop 5 Dramas: \n1a. Dirty John \n2a. Scandal \n3a. The Vampire Diaries \n4a. Dynasty \n5a. Dexter\n")
        recommendation2 = ("\nTop 5 Romance: \n1b. The L Word \n2b. Friends from Collage \n3b. Greys Anatomy \n4b. Jane the Virgin \n5b. Gilmore Girls\n")
        recommendation3 = (" ")
        recommendation4 = (" ")
        recommendation5 = (" ")
        
    elif feelings == 'nostalgic':
        recommendation = (f"\nSince you are feeling {feelings}, here are some TV genres to look at: Classic and Cult and Kids\n")
        recommendation1 = ("\nTop 5 Classic and cult: \n1a. Cheers \n2a. The Walking Dead \n3a. Episodes \n4a. Supernatural \n5a. Trailer Park Boys\n")
        recommendation2 = ("\nTop 5 Kids: \n1b. Sam and Cat \n2b. Raising Dion \n3b. Victorious \n4b. The Boss Baby: Back in Business \n5b. Barbie: Living in a Dream House\n")
        recommendation3 = (" ")
        recommendation4 = (" ")
        recommendation5 = (" ")
        
    elif feelings == 'dramatic':
        recommendation = (f"\nSince you are feeling {feelings}, here are some TV genres to look at: Dramas, Reality, Romance, and Thrillers\n")
        recommendation1 = ("\nTop 5 Dramas: \n1a. Dirty John \n2a. Scandal \n3a. The Vampire Diaries \n4a. Dynasty \n5a. Dexter\n")
        recommendation2 = ("\nTop 5 Reality: \n1b. The Bachelor \n2b. Rhythm Flow \n3b. Glow Up \n4b. Queer Eye \n5b. Girls Incarcerated\n")
        recommendation3 = ("\nTop 5 Romance: \n1c. The L Word \n2c. Friends from Collage \n3c. Greys Anatomy \n4c. Jane the Virgin \n5c. Gilmore Girls\n")
        recommendation4 = ("\nTop 5 Thrillers: \n1d. You \n2d. Breaking Bad \n3d. Designated Survivor \n4d. Dirty John \n5d. Quantico\n")
        recommendation5 = (" ")
        
    elif feelings == 'edgy':
        recommendation = (f"\nSince you are feeling {feelings}, here are some TV genres to look at: Horror, Mysteries, and Thrillers\n")
        recommendation1 = ("\nTop 5 Horror: \n1a. V Wars \n2a. American Horror Story \n3a. The Walking Dead \n4a. The Originals \n5a. Supernaturals\n")
        recommendation2 = ("\nTop 5 Mysteries: \n1b. How to get away with Murder \n2b. Criminal Minds \n3b. Dexter \n4b. Sherlock \n5b. Person of Interest\n")
        recommendation3 = ("\nTop 5 Thrillers: \n1c. You \n2c. Breaking Bad \n3c. Designated Survivor \n4c. Dirty John \n5c. Quantico\n")
        recommendation4 = (" ")
        recommendation5 = (" ")
        
    elif feelings == 'active':
        recommendation = (f"\nSince you are feeling {feelings}, here are some TV genres to look at: Action, Thrillers, and Horror\n")
        recommendation1 = ("\nTop 5 Action: \n1a. Daredevil \n2a. Jessica Jones \n3a. Luke Cage \n4a. The Umbrella Academy \n5a. Narcos\n")
        recommendation2 = ("\nTop 5 Thrillers: \n1b. You \n2b. Breaking Bad \n3b. Designated Survivor \n4b. Dirty John \n5b. Quantico\n")
        recommendation3 = ("\nTop 5 Horror: \n1c. V Wars \n2c. American Horror Story \n3c. The Walking Dead \n4c. The Originals \n5c. Supernaturals\n")
        recommendation4 = (" ")
        recommendation5 = (" ")
        

    print(recommendation, recommendation1, recommendation2, recommendation3, recommendation4, recommendation5)


    if feelings == 'happy':
        recommendation = (f"\nSince you are feeling {feelings}, here are some movie genres to look at: Comedies, Holidays, Stand-Up Comedy\n")
        recommendation1 = ("\nTop 5 Comedies: \n1a. Step Brothers \n2a. Leap Year \n3a. Pink Panther \n4a. Paul Blart Mall Cop \n5a. Get Smart\n")
        recommendation2 = ("\nTop 5 Holidays: \n1b. How the Grinch Stole Christmas \n2b. Christmas with the Kranks \n3b. The Knight before Christmas \n4b. A Holiday Engagement \n5b. Klaus\n")
        recommendation3 = ("\nTop 5 Stand-Up Comedy: \n1c. John Mulaney: Kid Gorgeous \n2c. Seth Myers: Lobby Baby \n3c. Kevin Hart: Laugh at my Pain \n4c. Ali Wong: Hard Knock Wife \n5c. John Mulaney: The Comeback Kid\n")
        recommendation4 = (" ")
        recommendation5 = (" ")
        
    elif feelings == 'sad':
        recommendation = (f"\nSince you are feeling {feelings}, here are some movie genres to look at: Comedies, Romance, Stand-Up Comedy\n")
        recommendation1 = ("\nTop 5 Comedies: \n1a. Step Brothers \n2a. Leap Year \n3a. Pink Panther \n4a. Paul Blart Mall Cop \n5a. Get Smart\n")
        recommendation2 = ("\nTop 5 Romance: \n1b. To All the Boys I've Loved Before \n2b. The Kissing Booth \n3b. The Princess Switch \n4b The Perfect Date \n5b P.S. I Love You\n")
        recommendation3 = ("\nTop 5 Stand-Up Comedy: \n1c. John Mulaney: Kid Gorgeous \n2c. Seth Myers: Lobby Baby \n3c. Kevin Hart: Laugh at my Pain \n4c. Ali Wong: Hard Knock Wife \n5c. John Mulaney: The Comeback Kid\n")
        recommendation4 = (" ")
        recommendation5 = (" ")
        
    elif feelings == 'goofy':
        recommendation = (f"\nSince you are feeling {feelings}, here are some movie genres to look at: Action, Comedies, Stand-Up Comedy\n")
        recommendation1 = ("\nTop 5 Comedies: \n1a. Step Brothers \n2a. Leap Year \n3a. Pink Panther \n4a. Paul Blart Mall Cop \n5a. Get Smart\n")
        recommendation2 = ("\nTop 5 Romance: \n1b. To All the Boys I've Loved Before \n2b. The Kissing Booth \n3b. The Princess Switch \n4b The Perfect Date \n5b P.S. I Love You\n")
        recommendation3 = ("\nTop 5 Stand-Up Comedy: \n1c. John Mulaney: Kid Gorgeous \n2c. Seth Myers: Lobby Baby \n3c. Kevin Hart: Laugh at my Pain \n4c. Ali Wong: Hard Knock Wife \n5c. John Mulaney: The Comeback Kid\n")
        recommendation4 = (" ")
        recommendation5 = (" ")
        
    elif feelings == 'mysterious':
        recommendation = (f"\nSince you are feeling {feelings}, here are some movie genres to look at: Action, Horror, Thrillers\n")
        recommendation1 = ("\nTop 5 Action: \n1a. Bounty Hunter \n2a. Spider Man \n3a. Charlie's Angels \n4a. National Treasure \n5a. Avengers Infinity War\n")
        recommendation2 = ("\nTop 5 Horror: \n1b. Hush \n2b. The Conjuring \n3b. 47 Meters Down \n4b Insidious \n5b Truth or Dare\n")
        recommendation3 = ("\nTop 5 Thrillers: \n1c. Limitless \n2c. Selfless \n3c. Mystic River \n4c. In the Tall Grass \n5c. The Departed\n")
        recommendation4 = (" ")
        recommendation5 = (" ")
        
    elif feelings == 'childish':
        recommendation = (f"\nSince you are feeling {feelings}, here are some movie genres to look at: Anime, Children & Family\n")
        recommendation1 = ("\nTop 5 Anime: \n1a. A Silent Voice \n2a. No Game and No Life: Zero \n3a. Flavors of Youth \n4a. The Garden of Words \n5a. In this Corner of the World\n")
        recommendation2 = ("\nTop 5 Children & Family: \n1b. Incredibles 2 \n2b. The Grinch \n3b. Mary Poppins Returns \n4b. The Princess and the Frog \n5b. The Cat in the Hat\n")
        recommendation3 = (" ")
        recommendation4 = (" ")
        recommendation5 = (" ")
        
    elif feelings == 'nostalgic':
        recommendation = (f"\nSince you are feeling {feelings}, here are some movie genres to look at: Classics, Children & Family\n")
        recommendation1 = ("\nTop 5 Classics: \n1a. Grease \n2a. Pulp Fiction \n3a. Oceans 11 \n4a. Indiana Jones \n5a. Charlottes Web\n")
        recommendation2 = ("\nTop 5 Children & Family: \n1b. Incredibles 2 \n2b. The Grinch \n3b. Mary Poppins Returns \n4b. The Princess and the Frog \n5b. The Cat in the Hat\n")
        recommendation3 = (" ")
        recommendation4 = (" ")
        recommendation5 = (" ")
        
    elif feelings == 'adventurous':
        recommendation = (f"\nSince you are feeling {feelings}, here are some movie genres to look at: Crime, Sci-Fi and Fantasy\n")
        recommendation1 = ("\nTop 5 Crime: \n1a. The Irishman \n2a. Spring Breakers \n3a. El Camino \n4a. Bright \n5a. The Captive\n")
        recommendation2 = ("\nTop 5 Sci-Fi and Fantasy: \n1b. Star Wars the Last Jedi \n2b. The Matrix \n3b. Black Panther \n4b. Bird Box \n5b. The Clash of Titans\n")
        recommendation3 = (" ")
        recommendation4 = (" ")
        recommendation5 = (" ")
        
    elif feelings == 'curious':
        recommendation = (f"\nSince you are feeling {feelings}, here are some movie genres to look at: Crime, Sci-Fi and Fantasy, Thrillers\n")
        recommendation1 = ("\nTop 5 Crime: \n1a. The Irishman \n2a. Spring Breakers \n3a. El Camino \n4a. Bright \n5a. The Captive\n")
        recommendation2 = ("\nTop 5 Sci-Fi and Fantasy: \n1b. Star Wars the Last Jedi \n2b. The Matrix \n3b. Black Panther \n4b. Bird Box \n5b. The Clash of Titans\n")
        recommendation3 = ("\nTop 5 Thrillers: \n1c. Limitless \n2c. Selfless \n3c. Mystic River \n4c. In the Tall Grass \n5c. The Departed\n")
        recommendation4 = (" ")
        recommendation5 = (" ")
        
    elif feelings == 'romantic':
        recommendation = (f"\nSince you are feeling {feelings}, here are some movie genres to look at: Dramas, Romance\n")
        recommendation1 = ("\nTop 5 Dramas: \n1a. Marriage Story \n2a. After \n3a. Room \n4a. The Theory of Everything \n5a. The King\n")
        recommendation2 = ("\nTop 5 Romance: \n1b. To All the Boys I've Loved Before \n2b. The Kissing Booth \n3b. The Princess Switch \n4b. The Perfect Date \n5b. P.S. I Love You\n")
        recommendation3 = (" ")
        recommendation4 = (" ")
        recommendation5 = (" ")
        
    elif feelings == 'dramatic':
        recommendation = (f"\nSince you are feeling {feelings}, here are some movie genres to look at: Dramas, Romance, Thrillers\n")
        recommendation1 = ("\nTop 5 Dramas: \n1a. Marriage Story \n2a. After \n3a. Room \n4a. The Theory of Everything \n5a. The King\n")
        recommendation2 = ("\nTop 5 Romance: \n1b. To All the Boys I've Loved Before \n2b. The Kissing Booth \n3b. The Princess Switch \n4b. The Perfect Date \n5b. P.S. I Love You\n")
        recommendation3 = ("\nTop 5 Thrillers: \n1c. Limitless \n2c. Selfless \n3c. Mystic River \n4c. In the Tall Grass \n5c. The Departed\n")
        recommendation4 = (" ")
        recommendation5 = (" ")
        
    elif feelings == 'girly':
        recommendation = (f"\nSince you are feeling {feelings}, here are some movie genres to look at: Dramas, Romance\n")
        recommendation1 = ("\nTop 5 Dramas: \n1a. Marriage Story \n2a. After \n3a. Room \n4a. The Theory of Everything \n5a. The King\n")
        recommendation2 = ("\nTop 5 Romance: \n1b. To All the Boys I've Loved Before \n2b. The Kissing Booth \n3b. The Princess Switch \n4b. The Perfect Date \n5b. P.S. I Love You\n")
        recommendation3 = (" ")
        recommendation4 = (" ")
        recommendation5 = (" ")
        
    elif feelings == 'festive':
        recommendation = (f"\nSince you are feeling {feelings}, here are some movie genres to look at: Holiday\n")
        recommendation1 = ("\nTop 5 Holiday: \n1a. How the Grinch Stole Christmas \n2a. Christmas with the Kranks \n3a. The Knight before Christmas \n4a. A Holiday Engagement \n5a. Klaus\n")
        recommendation2 = (" ")
        recommendation3 = (" ")
        recommendation4 = (" ")
        recommendation5 = (" ")
        
    elif feelings == 'edgy':
        recommendation = (f"\nSince you are feeling {feelings}, here are some movie genres to look at: Horror, Thrillers\n")
        recommendation1 = ("\nTop 5 Horror: \n1a. Hush \n2a. The Conjuring \n3a. 47 Meters Down \n4a. Insidious \n5a. Truth or Dare\n")
        recommendation2 = ("\nTop 5 Thrillers: \n1b. Limitless \n2b. Selfless \n3b. Mystic River \n4b. In the Tall Grass \n5b. The Departed\n")
        recommendation3 = (" ")
        recommendation4 = (" ")
        recommendation5 = (" ")
        
    elif feelings == 'active':
        recommendation = (f"\nSince you are feeling {feelings}, here are some movie genres to look at: Sports\n")
        recommendation1 = ("\nTop 5 Sports: \n1a. The Game Changers \n2a. Miracle \n3a. Rocky \n4a. Icarus \n5a. A Mighty Team\n")
        recommendation2 = (" ")
        recommendation3 = (" ")
        recommendation4 = (" ")
        recommendation5 = (" ")
        

    print(recommendation, recommendation1, recommendation2, recommendation3, recommendation4, recommendation5)
    return recommendation
    
    
netflix_rec()
while True:
    explore = input("Which recommendation are you interested in? Type 'quit' if you are done looking at recommendations. ")  
    if explore == 'quit':
        print("Those are all of your recommendations and reviews!")
        break
    else:
        import requests
        url = "https://movie-database-imdb-alternative.p.rapidapi.com/"
        querystring = {"page":"1","r":"json","s":f'"{explore}"'}
        headers = {'x-rapidapi-host': "movie-database-imdb-alternative.p.rapidapi.com",
            'x-rapidapi-key': "f26bfaffe5msh0e6c9554b047fb1p123fc7jsn3dc0b09428bc"}
        response = requests.request("GET", url, headers=headers, params=querystring)
        review = response.json()
        Title = review['Search']
        index = 0
        for item in Title:
            name = Title[index]["imdbID"]

        print(f"Here's a link to the review for {explore}: https://www.imdb.com/title/{name}")
        print("If you liked the review, go to http://www.netflix.com and search the recommendation!\n")
# Out:
# Netflix Time!
# Are you happy
# Are you sad
# Are you goofy
# Are you festive
# Are you curious
# Are you girly
# Are you adventurous
# Are you childish
# Are you mysterious
# Are you romantic
# Are you nostalgic
# Are you dramatic
# Are you edgy
# Are you active
# Enter which mood you are currently in from the list above.: sad
#
# Since you are feeling sad, here are some TV genres to look at: Comedies, Romance, Stand-Up and Talk Shows
#
# Top 5 Comedies:
# 1a. Fuller House
# 2a. Merry Happy Whatever
# 3a. New Girl
# 4a. Atypical
# 5a. Schitts Creek
#
# Top 5 Romance:
# 1b. The L Word
# 2b. Friends from Collage
# 3b. Greys Anatomy
# 4b. Jane the Virgin
# 5b. Gilmore Girls
#
# Top 5 Stand-Up and Talk Shows:
# 1c. Kevin Hart Seriously Funny
# 2c. Tom Segura: Disgraceful
# 3c. Michelle Wolf Joke Show
# 4c. Kevin Hart: Laugh at my pain
# 5c. Adam Sandler 100% Fresh
#
#
# Since you are feeling sad, here are some movie genres to look at: Comedies, Romance, Stand-Up Comedy
#
# ...
